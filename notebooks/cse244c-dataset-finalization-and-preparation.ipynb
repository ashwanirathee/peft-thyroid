# %%
import os
import fnmatch
import scipy.io as sio
import glob 
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import xml.etree.ElementTree as ET
import json

# %%
dataset_path = '/kaggle/input/ddti-thyroid-ultrasound-images'

# %%
xml_file_paths = glob.glob(os.path.join(dataset_path, '*.xml'))

# %%
len(xml_file_paths)
# Out:
# 390

# %%
rows = []

for file_path in xml_file_paths:
    # Load the XML file
    tree = ET.parse(file_path)
    root = tree.getroot()
    
    data = {}
    for child in root:
        if child.tag in ["number", "tirads"]:
            data[child.tag] = child.text
            # print(child.tag, child.attrib, child.text)
    if data["tirads"] == None:
        continue
    rows.append(data)

# Correct capitalization of pd.DataFrame
df = pd.DataFrame(rows)
df
# Out:
#     number tirads
# 0      128     4c
# 1      346      3
# 2      142     4c
# 3      127      2
# 4      338     4c
# ..     ...    ...
# 293    263     4b
# 294    269     4b
# 295    295     4a
# 296    301     4a
# 297     44     4a
#
# [298 rows x 2 columns]

# %%
ids = []
image_arrays = []
labels = []
for idx, row  in df.iterrows():
    file_path = f"/kaggle/input/ddti-thyroid-ultrasound-images/{row['number']}_1.jpg"

    if not os.path.exists(file_path):
        print(f"Skipping: {file_path} (file not found)")
        continue
    # Do your processing here
    print(f"Processing: {file_path} with triad score: {row['tirads']}")
    # Load image as PIL Image
    img = Image.open(file_path).convert('L')  # Convert to grayscale
    
    # Convert to NumPy array
    img_array = np.array(img).astype(np.float32)
    
    # Normalize to [0, 255] safely
    img_min = img_array.min()
    img_max = img_array.max()
    
    if img_max > img_min:
        img_normalized = (img_array - img_min) / (img_max - img_min)
    else:
        img_normalized = np.zeros_like(img_array)
    
    img_normalized = np.clip(img_normalized * 255, 0, 255).astype(np.uint8)
    
    # Convert back to PIL Image for classification
    img_pil = Image.fromarray(img_normalized)
    
    # # Ask for classification
    # result = ask_image(img_pil, "Classify the disease in this image according to triads score: ")
    
    # Plot the image and classification result
    # plt.figure(figsize=(6, 6))
    # plt.imshow(img_normalized, cmap='gray')
    # plt.title(row['tirads'])
    # plt.axis('off')
    # plt.show()
    # break
    ids.append(row['number'])
    image_arrays.append(img_normalized)
    labels.append(row['tirads'])

# Convert lists to arrays
patient_ids = np.array(ids)
image_arrays = np.array(image_arrays)
labels = np.array(labels)
# Out:
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/128_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/346_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/142_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/127_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/338_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/164_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/110_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/166_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/109_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/279_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/391_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/261_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/31_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/39_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/212_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/242_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/123_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/111_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/293_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/66_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/298_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/291_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/36_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/187_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/42_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/105_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/371_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/195_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/359_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/13_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/395_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/248_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/310_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/217_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/220_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/258_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/90_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/278_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/82_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/2_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/102_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/10_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/153_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/43_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/190_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/68_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/143_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/344_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/320_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/32_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/122_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/100_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/337_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/299_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/400_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/151_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/45_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/55_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/297_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/357_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/356_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/318_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/8_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/386_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/49_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/233_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/202_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/18_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/399_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/144_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/362_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/365_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/174_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/27_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/80_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/283_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/373_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/171_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/381_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/319_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/108_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/308_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/209_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/257_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/88_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/368_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/85_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/203_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/355_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/348_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/125_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/370_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/119_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/9_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/358_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/115_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/154_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/107_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/76_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/21_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/382_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/33_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/309_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/317_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/270_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/360_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/24_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/290_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/380_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/35_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/340_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/20_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/314_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/176_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/112_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/252_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/300_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/397_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/375_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/343_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/329_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/185_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/130_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/259_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/192_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/339_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/282_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/316_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/193_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/331_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/179_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/207_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/6_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/148_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/186_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/7_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/40_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/347_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/11_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/378_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/219_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/206_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/247_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/16_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/14_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/265_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/61_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/28_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/67_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/267_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/271_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/41_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/51_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/313_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/137_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/236_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/251_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/244_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/23_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/225_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/12_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/264_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/333_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/94_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/354_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/135_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/126_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/78_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/221_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/216_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/376_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/167_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/246_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/243_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/205_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/286_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/390_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/101_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/303_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/25_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/103_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/93_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/366_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/131_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/95_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/369_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/26_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/255_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/272_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/374_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/387_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/377_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/268_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/83_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/342_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/98_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/70_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/363_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/194_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/89_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/30_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/172_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/134_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/334_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/50_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/321_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/341_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/170_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/289_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/277_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/155_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/57_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/19_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/311_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/350_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/224_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/367_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/296_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/47_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/345_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/141_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/162_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/398_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/294_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/178_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/53_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/227_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/275_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/284_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/379_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/46_1.jpg with triad score: 5
# Skipping: /kaggle/input/ddti-thyroid-ultrasound-images/336_1.jpg (file not found)
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/184_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/34_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/215_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/231_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/121_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/168_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/177_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/364_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/211_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/118_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/352_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/22_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/160_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/307_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/56_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/330_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/304_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/197_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/48_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/15_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/335_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/302_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/288_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/17_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/156_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/54_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/79_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/198_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/204_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/285_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/383_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/38_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/361_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/113_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/52_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/4_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/353_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/292_1.jpg with triad score: 3
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/81_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/214_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/228_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/86_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/74_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/29_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/384_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/315_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/372_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/129_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/65_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/305_1.jpg with triad score: 2
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/306_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/73_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/394_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/91_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/3_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/351_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/180_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/201_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/5_1.jpg with triad score: 5
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/281_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/392_1.jpg with triad score: 4c
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/263_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/269_1.jpg with triad score: 4b
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/295_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/301_1.jpg with triad score: 4a
# Processing: /kaggle/input/ddti-thyroid-ultrasound-images/44_1.jpg with triad score: 4a

# %%
from sklearn.model_selection import train_test_split

# %%
# Get unique patient IDs and split
unique_ids = np.unique(patient_ids)
train_ids, temp_ids = train_test_split(unique_ids, test_size=0.3, random_state=42)
val_ids, test_ids = train_test_split(temp_ids, test_size=0.5, random_state=42)

# Create masks
train_mask = np.isin(patient_ids, train_ids)
val_mask = np.isin(patient_ids, val_ids)
test_mask = np.isin(patient_ids, test_ids)

# Apply masks
train_images, train_labels = images[train_mask], labels[train_mask]
val_images, val_labels = images[val_mask], labels[val_mask]
test_images, test_labels = images[test_mask], labels[test_mask]

# %%
print(train_images.shape)
print(test_images.shape)
print(val_images.shape)
# Out:
# (207, 360, 560)
# (45, 360, 560)
# (45, 360, 560)

# %%
train_images1 = train_images[:, np.newaxis, :, :]      # (207, 1, 360, 560)
train_images3 = np.repeat(train_images1, 3, axis=1)      # (207, 3, 360, 560)

val_images1 = val_images[:, np.newaxis, :, :]
val_images3 = np.repeat(val_images1, 3, axis=1)

test_images1 = test_images[:, np.newaxis, :, :]
test_images3 = np.repeat(test_images1, 3, axis=1)

# %%
print(train_images3.shape, train_ids.shape,train_labels.shape)
print(val_images3.shape, val_ids.shape,val_labels.shape)
print(test_images3.shape, test_ids.shape,test_labels.shape)
# Out:
# (207, 3, 360, 560) (207,) (207,)
# (45, 3, 360, 560) (45,) (45,)
# (45, 3, 360, 560) (45,) (45,)

# %%
from torchvision import transforms
import torch

# Define your augmentation pipeline
augment = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.RandomResizedCrop((360, 560), scale=(0.9, 1.1)),
    transforms.ToTensor()
])

aug_images = []
aug_labels = []
aug_ids = []
# 
n_augments = 4  # augment each image 4 times

for i in range(len(train_images3)):
    orig_img = train_images3[i]
    label = train_labels[i]
    id_ = train_ids[i]

    img_tensor = torch.tensor(orig_img)  # (3, 360, 560)
    
    # Original image (optional: include or skip)
    aug_images.append(img_tensor)
    aug_labels.append(label)
    aug_ids.append(id_)

    # Augmented versions
    for _ in range(n_augments):
        aug = augment(img_tensor)
        aug_images.append(aug)
        aug_labels.append(label)
        aug_ids.append(id_)

# Stack into final dataset
aug_images = torch.stack(aug_images)             # shape: (207 * (1+n_augments), 3, 360, 560)
# aug_labels = torch.tensor(aug_labels)            # shape: (207 * (1+n_augments),)
# aug_ids = torch.tensor(aug_ids)                  # shape: (207 * (1+n_augments),)

# %%
torch.save({
    'train_images': aug_images,
    'train_labels': aug_labels,
    'train_ids': aug_ids,
    'test_images': test_images3,
    'test_labels': test_labels,
    'test_ids': test_ids,
    'val_images': val_images3,
    'val_labels': val_labels,
    'val_ids': val_ids,
}, 'augmented_dataset.pt')

# %%
# Load the saved dataset
data = torch.load('augmented_dataset.pt', weights_only=False)

# Print sizes
print("Train images:", data['train_images'].shape)
print("Train labels:", len(data['train_labels']))
print("Train IDs:", len(data['train_ids']))  # list of strings

print("Val images:", data['val_images'].shape)
print("Val labels:", len(data['val_labels']))
print("Val IDs:", len(data['val_ids']))

print("Test images:", data['test_images'].shape)
print("Test labels:", len(data['test_labels']))
print("Test IDs:", len(data['test_ids']))
# Out:
# Train images: torch.Size([1035, 3, 360, 560])
# Train labels: 1035
# Train IDs: 1035
# Val images: (45, 3, 360, 560)
# Val labels: 45
# Val IDs: 45
# Test images: (45, 3, 360, 560)
# Test labels: 45
# Test IDs: 45

# %%
train_images.shape
# Out:
# (207, 360, 560)

# %%
augmented_images = []
original_images = torch.from_numpy(train_images).float() / 255.0  # Normalize to [0,1]

# Generate N augmentations per image
n_augments = 4

for img in original_images:
    pil_img = to_pil(img)
    augmented_images.append(img)  # original
    for _ in range(n_augments):
        aug = augment(pil_img)
        augmented_images.append(aug)

augmented_images = torch.stack(augmented_images)  # shape: (207 * 5, 3, 360, 560)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_35/3519353131.py in <cell line: 0>()
#      12         augmented_images.append(aug)
#      13
# ---> 14 augmented_images = torch.stack(augmented_images)  # shape: (207 * 5, 3, 360, 560)
#
# RuntimeError: stack expects each tensor to be equal size, but got [360, 560] at entry 0 and [1, 360, 560] at entry 1

# %%
# Save to file
np.savez_compressed("thyroid_images_and_labels.npz", patient_ids=patient_ids, images=image_arrays, labels=labels)
print("Saved images and labels to thyroid_images_and_labels.npz")
# Out:
# Saved images and labels to thyroid_images_and_labels.npz

# %%
data = np.load("/kaggle/working/thyroid_images_and_labels.npz")
images = data["images"]
labels = data["labels"]
patient_ids = data["patient_ids"]

# %%
len(patient_ids)
# Out:
# 297
